# %% [markdown]
# # Environment

# %%
import os
import numpy as np

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Configure

# %%
DATASET_ROOT = './datasets/yalefaces'
FEAT_TYPE = 'downsample'
FEAT_OUTPUT_FOLDER = f"{DATASET_ROOT}_{FEAT_TYPE}"

# %% [markdown]
# ### Load and Split

# %%
X_train, y_train = [], []
X_test, y_test = [], []
for f in [f for f in os.listdir(FEAT_OUTPUT_FOLDER) if f.startswith("subject") and f.endswith(".npy")]:
    path = os.path.join(FEAT_OUTPUT_FOLDER, f)
    feat = np.load(path)
    feat = feat / np.linalg.norm(feat)  # normalize

    if f.find("normal") == -1:  # use normal as test, others as train
        X_train.append(feat[:, np.newaxis])
        y_train.append(int(f[7:9]))
    else:
        X_test.append(feat[:, np.newaxis])
        y_test.append(int(f[7:9]))
X_train = np.concatenate(X_train, axis=1)
y_train = np.array(y_train)
X_test = np.concatenate(X_test, axis=1)
y_test = np.array(y_test)

# %% [markdown]
# # Algorithm

# %% [markdown]
# ### Solve and Predict

# %%
from sklearn.linear_model import Lasso

k = len(np.unique(y_train))

y_pred = []
scis = []
for i in range(X_test.shape[1]):
    clf = Lasso(alpha=1e-4)
    clf.fit(X_train, X_test[:, i])
    w = clf.coef_

    
    delta_ws = []
    for j in range(k):
        delta_w = np.zeros_like(w)
        delta_w[y_train == (j + np.min(y_train))] = w[y_train == (j + np.min(y_train))]
        delta_ws.append(delta_w)
    delta_ws = np.array(delta_ws)

    residuals = []
    for j in range(k):
        residuals.append(np.linalg.norm(X_test[:, i] - X_train @ delta_ws[j]))
    residuals = np.array(residuals)

    sci = (k * np.max(np.linalg.norm(delta_ws, ord=1, axis=1)) / np.linalg.norm(w, ord=1) - 1) / (k - 1)
    scis.append(sci)

    if sci >= 0.3:
        y_pred.append(np.argmin(residuals) + np.min(y_train))
    else: # reject
        y_pred.append(-1)

print(f"Precision: {np.mean(y_test == y_pred):.2f}")
# Out:
# Precision: 1.00

# %% [markdown]
# # Visualize

# %% [markdown]
# ### Coefficient

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(w)), w)
plt.title("Lasso Coefficients")
plt.xlabel("Feature")
plt.ylabel("Coefficient")
plt.show()

# %% [markdown]
# ### Residuals

# %%
plt.bar(range(len(residuals)), residuals)
plt.title("Residuals")
plt.xlabel("Subject")
plt.ylabel("Residual")
plt.show()
